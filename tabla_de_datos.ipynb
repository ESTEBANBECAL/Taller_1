# %%
import pandas as pd
archivo_excel = 'C:/Users/esteb/OneDrive/Documents/Maestria/I/Programacion/Trabajos/I/Repositorio/Datos.xlsx'
datos = pd.read_excel(archivo_excel)
datos.head()
datos.describe()
# Out:
#                 a           b         c             d         e         f  \
# count    9.000000    9.000000  9.000000  9.000000e+00  9.000000  9.000000
# mean   100.000000  130.000000  0.277778  2.014167e-04  0.132422  1.620556
# std     54.772256   27.386128  0.151993  3.244205e-04  0.122094  0.101076
# min     20.000000   90.000000  0.056000  1.000000e-08  0.003800  1.436000
# 25%     60.000000  110.000000  0.167000  2.700000e-06  0.034800  1.565000
# 50%    100.000000  130.000000  0.278000  4.000000e-05  0.099000  1.646000
# 75%    140.000000  150.000000  0.389000  2.300000e-04  0.204800  1.702000
# max    180.000000  170.000000  0.500000  9.600000e-04  0.353100  1.725000
#
#               g         h         i         j         k         l         m  \
# count  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000  9.000000
# mean   2.672222  3.508556  2.624556  0.024210  0.006771  1.250222  1.872222
# ...

# %%
#La tabla de datos se subio con la siguiente nomenclatura; 
from PIL import Image
ruta_imagen = ruta_imagen = r"C:\Users\esteb\OneDrive\Documents\Maestria\I\Programacion\Trabajos\I\Repositorio\Imagen tabla.png"
imagen_tabla = Image.open(ruta_imagen)
imagen_tabla.show()
